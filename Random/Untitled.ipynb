# 62492  1.571440e+12  106.933594  32.714844  -433.593750   14.160156
# 62493  1.571440e+12   83.984375  34.667969  -239.746094   40.527344
# 62494  1.571440e+12  -31.738281  30.761719    82.519531   72.753906
# 62495  1.571440e+12  -39.550781  31.738281  -148.925781   49.316406
# 62508  1.571440e+12   -3.417969  40.039062  -204.101562   36.132812
# 62509  1.571440e+12   96.679688  42.968750  -519.531250   11.230469
# 62510  1.571440e+12   81.054688  38.574219  -420.898438   21.972656
# 62511  1.571440e+12  -46.875000  41.015625  -101.074219   47.851562
# 62512  1.571440e+12  -70.800781  43.945312  -149.414062   39.062500
# 62513  1.571440e+12   59.082031  53.710938  -390.136719   13.183594
# 62514  1.571440e+12  111.328125  53.710938  -430.175781   30.761719
# 62515  1.571440e+12    0.488281  41.992188  -245.117188   73.242188
# 62516  1.571440e+12  -76.171875  40.039062  -144.042969   50.292969
# 62517  1.571440e+12    1.953125  39.550781  -433.105469  -11.230469
# 62518  1.571440e+12   94.726562  44.921875  -487.304688    6.347656
# 62519  1.571440e+12   22.949219  49.316406  -290.039062   63.964844
#
# [35364 rows x 5 columns]

# %%
plt.plot(df['time'][:1000], df['TP9'][:1000])

# %%
# Read the CSV file as a NumPy array
data = np.loadtxt('reg_meditate_shrooms.csv', delimiter=',', skiprows=1)
data
# Out:
# array([[ 1.57143990e+12,             nan,             nan,
#          6.25976562e+02, -5.81054688e+01,             nan],
#        [ 1.57143990e+12,             nan,             nan,
#         -9.80468750e+02,  9.91210938e+01,             nan],
#        [ 1.57143990e+12,             nan,             nan,
#          9.85839844e+02, -5.51757812e+01,             nan],
#        ...,
#        [ 1.57144015e+12,  1.95312500e+00,  3.95507812e+01,
#         -4.33105469e+02, -1.12304688e+01,             nan],
#        [ 1.57144015e+12,  9.47265625e+01,  4.49218750e+01,
#         -4.87304688e+02,  6.34765625e+00,             nan],
#        [ 1.57144015e+12,  2.29492188e+01,  4.93164062e+01,
#         -2.90039062e+02,  6.39648438e+01,             nan]])

# %%
# Some information about the channels
ch_names = ['time', 'TP9', 'AF7', 'AF8', 'TP10', 'AUX']  # TODO: finish this list

# Sampling rate of the Nautilus machine
sfreq = 500  # Hz

# Create the info structure needed by MNE
info = mne.create_info(ch_names, sfreq)

# Finally, create the Raw object
raw = mne.io.RawArray(data, info)

# Plot it!
raw.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-d05e0f40fa2f> in <module>
#       9
#      10 # Finally, create the Raw object
# ---> 11 raw = mne.io.RawArray(data, info)
#      12
#      13 # Plot it!
#
# ~/anaconda3/lib/python3.6/site-packages/mne/io/array/array.py in __init__(self, data, info, first_samp, verbose)
#
# ~/anaconda3/lib/python3.6/site-packages/mne/utils.py in verbose(function, *args, **kwargs)
#     795         with use_log_level(verbose_level):
#     796             return function(*args, **kwargs)
# --> 797     return function(*args, **kwargs)
#     798
#     799
#
# ~/anaconda3/lib/python3.6/site-packages/mne/io/array/array.py in __init__(self, data, info, first_samp, verbose)
#      63             raise ValueError('len(data) (%s) does not match '
#      64                              'len(info["ch_names"]) (%s)'
# ---> 65                              % (len(data), len(info['ch_names'])))
#      66         assert len(info['ch_names']) == info['nchan']
#      67         info = info.copy()  # do not modify original info
#
# ValueError: len(data) (62520) does not match len(info["ch_names"]) (6)
